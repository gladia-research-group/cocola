# %%
import os
import librosa
from IPython.display import Audio
os.environ['CUDA_VISIBLE_DEVICES'] = '0' 
import torch
import torchaudio

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
from data.moisesdb_contrastive_online import MoisesdbContrastivePreprocessed #TODO
from pathlib import Path

import lightning as L
from torch.utils.data import DataLoader, ConcatDataset
import torch

from contrastive_model import constants
from feature_extraction.feature_extraction import CoColaFeatureExtractor

# %%
chunk_duration = 5.0
target_sample_rate = 16000
generate_submixtures=True
preprocess_transform = None

# %%
feature_extractor_type = constants.ModelFeatureExtractorType.HPSS #TODO
#feature_extractor_type = constants.ModelFeatureExtractorType.MEL_SPECTROGRAM
feature_extractor = CoColaFeatureExtractor(feature_extractor_type=feature_extractor_type)
runtime_transform = feature_extractor

# %%
def _get_moisesdb_splits(stage: str):
        device = "cuda" if torch.cuda.is_available() else "cpu"
        root_dir = "/disk1/demancum/hp_datasets/moisesdb_contrastive" #TODO
        train_dataset, val_dataset, test_dataset = None, None, None

        if stage == "fit":
            train_dataset = MoisesdbContrastivePreprocessed(
                root_dir=root_dir,
                split="train",
                #preprocess=True,
                chunk_duration=chunk_duration,
                target_sample_rate=target_sample_rate,
                generate_submixtures=generate_submixtures,
                device=device,
                preprocess_transform=preprocess_transform,
                runtime_transform=runtime_transform)

            val_dataset = MoisesdbContrastivePreprocessed(
                root_dir=root_dir,
                split="valid",
                #preprocess=True,
                chunk_duration=chunk_duration,
                target_sample_rate=target_sample_rate,
                generate_submixtures=generate_submixtures,
                device=device,
                preprocess_transform=preprocess_transform,
                runtime_transform=runtime_transform)
        elif stage == "test":
            test_dataset = MoisesdbContrastivePreprocessed(
                root_dir=root_dir,
                split="test",
                #preprocess=True,
                chunk_duration=chunk_duration,
                target_sample_rate=target_sample_rate,
                generate_submixtures=generate_submixtures,
                device=device,
                preprocess_transform=preprocess_transform,
                runtime_transform=runtime_transform)

        return train_dataset, val_dataset, test_dataset

# %%
train_dataset, val_dataset, test_dataset = _get_moisesdb_splits(stage="fit")
# Out:
# Building track index: 100%|██████████| 216/216 [00:00<00:00, 6622.20it/s]
# Building track index: 100%|██████████| 12/12 [00:00<00:00, 5839.62it/s]

# %%
#import cProfile
#cProfile.run('train_dataset[0]')

import cProfile, pstats, io
from pstats import SortKey
pr = cProfile.Profile()
pr.enable()
train_dataset[0]
pr.disable()
s = io.StringIO()
sortby = SortKey.TIME
ps = pstats.Stats(pr, stream=s).sort_stats(sortby)
ps.print_stats()
print(s.getvalue())
# Out:
#          2280297 function calls (2243953 primitive calls) in 1.752 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
# 6036/6004    0.215    0.000    0.256    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/binding/ffi.py:190(__call__)
#       156    0.146    0.001    0.443    0.003 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/inspect.py:969(getmodule)
# 3402/3277    0.122    0.000    0.124    0.000 {built-in method __new__ of type object at 0x866f00}
#        17    0.108    0.006    0.108    0.006 {built-in method torch._ops.torchaudio_sox.load_audio_file}
#      3222    0.077    0.000    0.077    0.000 {built-in method posix.stat}
#       330    0.069    0.000    0.069    0.000 {built-in method io.open_code}
#     18767    0.069    0.000    0.069    0.000 {built-in method posix.lstat}
#       437    0.061    0.000    0.061    0.000 {method '__exit__' of '_io._IOBase' objects}
#    292036    0.052    0.000    0.066    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/inspect.py:283(ismodule)
# 309003/308779    0.047    0.000    0.076    0.000 {built-in method builtins.hasattr}
#        68    0.034    0.001    0.034    0.001 {built-in method posix.open}
#       330    0.034    0.000    0.034    0.000 {built-in method marshal.loads}
#         1    0.025    0.025    0.025    0.025 {built-in method _ctypes.dlopen}
#    297940    0.025    0.000    0.030    0.000 {method 'get' of 'dict' objects}
#       284    0.025    0.000    0.079    0.000 {built-in method io.open}
# 385337/385333    0.022    0.000    0.024    0.000 {built-in method builtins.isinstance}
#      1670    0.021    0.000    0.127    0.000 <frozen posixpath>:421(_joinrealpath)
#     18981    0.020    0.000    0.032    0.000 <frozen posixpath>:71(join)
#        34    0.018    0.001    0.018    0.001 {built-in method posix.unlink}
#         2    0.015    0.008    0.015    0.008 {built-in method torch.stack}
#       395    0.013    0.000    0.013    0.000 {method 'read' of '_io.BufferedReader' objects}
# 1711/1708    0.010    0.000    0.030    0.000 {built-in method builtins.__build_class__}
#     11/10    0.009    0.001    0.009    0.001 {built-in method _imp.create_dynamic}
#  2628/288    0.009    0.000    0.076    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/context.py:428(install_registry)
# 25261/24456    0.009    0.000    0.013    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/types/abstract.py:121(__hash__)
#     19564    0.008    0.000    0.016    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/utils.py:515(stream_list)
#        36    0.007    0.000    0.007    0.000 {built-in method numpy.fft._pocketfft_internal.execute}
#         2    0.007    0.004    0.366    0.183 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/librosa/core/spectrum.py:45(stft)
#        34    0.007    0.000    0.007    0.000 {built-in method posix.mkdir}
#        44    0.007    0.000    0.007    0.000 {built-in method posix.listdir}
#        34    0.007    0.000    0.007    0.000 {method 'close' of '_io.BufferedRandom' objects}
# 6122/5599    0.006    0.000    0.564    0.000 <frozen importlib._bootstrap>:1207(_handle_fromlist)
#     40583    0.006    0.000    0.006    0.000 {method 'startswith' of 'str' objects}
# 18736/2789    0.006    0.000    1.180    0.000 {built-in method builtins.getattr}
#     23844    0.006    0.000    0.025    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/templates.py:1314(new_registrations)
#      6374    0.006    0.000    0.014    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/event.py:404(end_event)
# 23287/23087    0.006    0.000    0.029    0.000 {built-in method builtins.next}
#      6374    0.005    0.000    0.015    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/event.py:390(start_event)
#      1097    0.005    0.000    0.124    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/templates.py:879(make_overload_template)
#     24390    0.005    0.000    0.007    0.000 <frozen posixpath>:41(_get_sep)
#     12748    0.005    0.000    0.011    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/event.py:100(__init__)
#      1872    0.005    0.000    0.006    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/types/functions.py:245(__init__)
#     12748    0.005    0.000    0.006    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/event.py:209(broadcast)
#     19564    0.005    0.000    0.006    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/utils.py:524(sublist_iterator)
#        46    0.005    0.000    0.021    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typeconv/castgraph.py:92(propagate)
#      2336    0.004    0.000    0.024    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/base.py:352(install_registry)
#      2036    0.004    0.000    0.004    0.000 {built-in method _abc._abc_init}
#       383    0.004    0.000    0.078    0.000 <frozen importlib._bootstrap_external>:1607(find_spec)
#     12748    0.004    0.000    0.006    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/event.py:66(_guard_kind)
#      6036    0.004    0.000    0.020    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/binding/ffi.py:72(__enter__)
#      6036    0.004    0.000    0.020    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/binding/ffi.py:78(__exit__)
#       292    0.004    0.000    0.258    0.001 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/cpu.py:60(load_additional_registries)
#      1862    0.004    0.000    0.202    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/inspect.py:932(getsourcefile)
#         1    0.004    0.004    0.006    0.006 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/binding/executionengine.py:1(<module>)
#     379/2    0.004    0.000    1.752    0.876 {built-in method builtins.exec}
#     29023    0.004    0.000    0.004    0.000 {method 'endswith' of 'str' objects}
#        76    0.004    0.000    0.005    0.000 {built-in method builtins.eval}
#  4270/674    0.004    0.000    0.005    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/ir.py:318(_rec_list_vars)
#       260    0.003    0.000    0.004    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/templates.py:1158(make_overload_attribute_template)
# 6687/3581    0.003    0.000    0.011    0.000 {method 'format' of 'str' objects}
# 2299/2294    0.003    0.000    0.019    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/types/abstract.py:61(__call__)
#      5132    0.003    0.000    0.006    0.000 <frozen posixpath>:60(isabs)
#         4    0.003    0.001    0.004    0.001 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/librosa/filters.py:127(mel)
#      2543    0.003    0.000    0.009    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/types/abstract.py:49(_intern)
#         2    0.003    0.001    1.641    0.821 /home/demancum/cocola_test/cocola/feature_extraction/feature_extraction.py:33(forward)
#     36066    0.003    0.000    0.003    0.000 {built-in method posix.fspath}
#      6033    0.002    0.000    0.016    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/base.py:1246(enter_fn)
#     18938    0.002    0.000    0.002    0.000 {method 'partition' of 'str' objects}
#       346    0.002    0.000    0.086    0.000 <frozen importlib._bootstrap>:1054(_find_spec)
#      2888    0.002    0.000    0.005    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/target_extension.py:53(get_local_target)
#      1097    0.002    0.000    0.138    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/extending.py:129(decorate)
#      6033    0.002    0.000    0.015    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/base.py:1249(exit_fn)
#      3461    0.002    0.000    0.011    0.000 <frozen posixpath>:397(abspath)
# 29132/28914    0.002    0.000    0.002    0.000 {built-in method builtins.len}
#      1472    0.002    0.000    0.002    0.000 {method 'copy' of 'dict' objects}
#     27182    0.002    0.000    0.002    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/types/abstract.py:96(key)
#       330    0.002    0.000    0.178    0.001 <frozen importlib._bootstrap_external>:1007(get_code)
# 26154/24596    0.002    0.000    0.003    0.000 {built-in method builtins.hash}
#        58    0.002    0.000    0.006    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/collections/__init__.py:350(namedtuple)
#         4    0.002    0.001    0.002    0.001 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/librosa/core/spectrum.py:1654(power_to_db)
#       660    0.002    0.000    0.006    0.000 <frozen importlib._bootstrap_external>:437(cache_from_source)
#         8    0.002    0.000    0.002    0.000 {built-in method numpy.zeros}
#      1097    0.002    0.000    0.002    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/extending.py:62(overload)
#      3810    0.002    0.000    0.006    0.000 {built-in method builtins.any}
#      1406    0.002    0.000    0.013    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/binding/value.py:220(is_declaration)
#    452/35    0.002    0.000    1.596    0.046 <frozen importlib._bootstrap>:1165(_find_and_load)
#      3461    0.002    0.000    0.004    0.000 <frozen posixpath>:389(normpath)
#        11    0.002    0.000    0.002    0.000 {built-in method builtins.sum}
#      2911    0.002    0.000    0.006    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typeconv/castgraph.py:39(insert)
#      1757    0.002    0.000    0.030    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/inspect.py:957(getabsfile)
#        64    0.002    0.000    0.005    0.000 {built-in method _pickle.loads}
# 4462/4208    0.002    0.000    0.002    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/types/abstract.py:124(__eq__)
#      1309    0.002    0.000    0.002    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/ir/_utils.py:24(deduplicate)
# 2378/1950    0.002    0.000    0.002    0.000 {built-in method _abc._abc_subclasscheck}
#      2243    0.002    0.000    0.004    0.000 <frozen importlib._bootstrap_external>:126(_path_join)
#     19889    0.002    0.000    0.002    0.000 {built-in method builtins.iter}
#      1678    0.002    0.000    0.002    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/utils.py:485(__setitem__)
#      2036    0.002    0.000    0.128    0.000 <frozen abc>:105(__new__)
#      2243    0.002    0.000    0.002    0.000 <frozen importlib._bootstrap_external>:128(<listcomp>)
#      1670    0.002    0.000    0.134    0.000 <frozen posixpath>:412(realpath)
#     349/5    0.002    0.000    1.596    0.319 <frozen importlib._bootstrap>:1120(_find_and_load_unlocked)
#     15674    0.002    0.000    0.002    0.000 {method 'append' of 'list' objects}
#       575    0.002    0.000    0.003    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/functools.py:35(update_wrapper)
# 3149/1373    0.002    0.000    0.010    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/ir/_utils.py:44(__str__)
#       138    0.002    0.000    0.038    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/codegen.py:1091(<setcomp>)
#      6387    0.001    0.000    0.028    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/binding/ffi.py:134(__getattr__)
#      2100    0.001    0.000    0.003    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/inspect.py:892(getfile)
#     18767    0.001    0.000    0.001    0.000 {built-in method _stat.S_ISLNK}
#     12748    0.001    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/event.py:108(kind)
#       292    0.001    0.000    0.046    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/context.py:744(load_additional_registries)
#      2342    0.001    0.000    0.006    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/base.py:368(insert_func_defn)
#       943    0.001    0.000    0.009    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/ir/values.py:544(_to_string)
#       163    0.001    0.000    0.004    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/inspect.py:2331(_signature_from_function)
#     91/37    0.001    0.000    0.003    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/re/_parser.py:516(_parse)
#      1768    0.001    0.000    0.018    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/binding/module.py:220(__next__)
#      1545    0.001    0.000    0.002    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/templates.py:1250(register_global)
#      7216    0.001    0.000    0.002    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/inspect.py:942(<genexpr>)
#         4    0.001    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numpy/core/numeric.py:932(tensordot)
#       341    0.001    0.000    0.008    0.000 <frozen importlib._bootstrap>:493(_init_module_attrs)
#     341/5    0.001    0.000    1.593    0.319 <frozen importlib._bootstrap>:666(_load_unlocked)
#      3461    0.001    0.000    0.001    0.000 {built-in method posix._path_normpath}
#       647    0.001    0.000    0.002    0.000 <frozen importlib._bootstrap>:179(_get_module_lock)
# 5265/5264    0.001    0.000    0.003    0.000 {method 'join' of 'str' objects}
#      2100    0.001    0.000    0.005    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/torch/package/package_importer.py:695(_patched_getfile)
#      1886    0.001    0.000    0.009    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/binding/ffi.py:329(close)
#      5586    0.001    0.000    0.002    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/inspect.py:939(<genexpr>)
# 2410/2405    0.001    0.000    0.003    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/ir/_utils.py:54(get_reference)
#   167/163    0.001    0.000    0.005    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/inspect.py:2435(_signature_from_callable)
#       647    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:100(acquire)
#      1866    0.001    0.000    0.010    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/binding/ffi.py:372(__del__)
#       898    0.001    0.000    0.005    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/ir/instructions.py:13(__init__)
#       860    0.001    0.000    0.008    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/binding/value.py:157(name)
#      1607    0.001    0.000    0.003    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/context.py:513(_insert_global)
#       378    0.001    0.000    0.003    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/ipykernel/ipkernel.py:775(_clean_thread_parent_frames)
#    177/31    0.001    0.000    0.003    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/re/_compiler.py:37(_compile)
#       125    0.001    0.000    0.002    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/enum.py:242(__set_name__)
#       341    0.001    0.000    0.002    0.000 <frozen importlib._bootstrap_external>:778(spec_from_file_location)
#       346    0.001    0.000    0.081    0.000 <frozen importlib._bootstrap_external>:1467(_get_spec)
#       647    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:125(release)
#       330    0.001    0.000    0.132    0.000 <frozen importlib._bootstrap_external>:1127(get_data)
#      5747    0.001    0.000    0.002    0.000 {method 'add' of 'set' objects}
#       909    0.001    0.000    0.008    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/binding/module.py:251(_next)
#       660    0.001    0.000    0.002    0.000 <frozen importlib._bootstrap_external>:132(_path_split)
#       325    0.001    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/bytecode.py:219(_patched_opargs)
#       260    0.001    0.000    0.064    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/templates.py:899(_get_target_registry)
#      2911    0.001    0.000    0.003    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typeconv/castgraph.py:48(get)
#       859    0.001    0.000    0.007    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/binding/module.py:240(_next)
#      1357    0.001    0.000    0.005    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/ir/values.py:537(__init__)
#      3796    0.001    0.000    0.001    0.000 {built-in method builtins.max}
#      1816    0.001    0.000    0.013    0.000 <frozen genericpath>:16(exists)
#      2785    0.001    0.000    0.002    0.000 {built-in method builtins.issubclass}
#      6387    0.001    0.000    0.001    0.000 {method 'acquire' of '_thread.RLock' objects}
#      1373    0.001    0.000    0.004    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/ir/_utils.py:16(register)
#      1373    0.001    0.000    0.004    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/ir/values.py:557(_set_name)
#        73    0.001    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/re/_compiler.py:243(_optimize_charset)
#      2888    0.001    0.000    0.002    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/target_extension.py:47(current_target)
#       367    0.001    0.000    0.011    0.000 {built-in method builtins.sorted}
#       222    0.001    0.000    0.005    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/templates.py:1289(decorator)
#      1211    0.001    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/base.py:138(append)
#      1238    0.001    0.000    0.003    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/templates.py:1240(register)
#      1238    0.001    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/context.py:545(insert_function)
#      2927    0.001    0.000    0.002    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typeconv/castgraph.py:65(__getitem__)
#      3189    0.001    0.000    0.002    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/types/abstract.py:127(__ne__)
#      2396    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:244(_verbose_message)
#      1545    0.001    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/context.py:499(_lookup_global)
#      1484    0.001    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/binding/value.py:87(__init__)
#       330    0.001    0.000    0.035    0.000 <frozen importlib._bootstrap_external>:727(_compile_bytecode)
#       243    0.001    0.000    0.013    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/extending.py:207(decorate)
#       330    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:642(_classify_pyc)
#        96    0.001    0.000    0.456    0.005 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/inspect.py:1658(getframeinfo)
#      3779    0.001    0.000    0.001    0.000 {built-in method builtins.setattr}
#        16    0.001    0.000    0.001    0.000 {built-in method builtins.compile}
#    292/32    0.001    0.000    0.077    0.002 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/context.py:415(_load_builtins)
#       372    0.001    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/inspect.py:2669(__init__)
#         7    0.001    0.000    0.001    0.000 {method 'readlines' of '_io._IOBase' objects}
#       243    0.001    0.000    0.063    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/templates.py:1092(_init_once)
#      2336    0.001    0.000    0.004    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/base.py:372(_insert_getattr_defn)
#      1991    0.001    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/types/abstract.py:20(_autoincr)
#     330/5    0.001    0.000    1.592    0.318 <frozen importlib._bootstrap_external>:934(exec_module)
#       990    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:84(_unpack_uint32)
#      1358    0.001    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/cpu_options.py:131(__init__)
#       341    0.001    0.000    0.002    0.000 <frozen importlib._bootstrap_external>:1602(_get_spec)
#      6169    0.001    0.000    0.001    0.000 {method 'rstrip' of 'str' objects}
#       189    0.001    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/ipykernel/ipkernel.py:790(<setcomp>)
#      2592    0.001    0.000    0.001    0.000 {method 'rpartition' of 'str' objects}
#      2336    0.001    0.000    0.004    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/base.py:380(_insert_cast_defn)
#       189    0.001    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/threading.py:1501(enumerate)
#      2488    0.001    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/inspect.py:292(isclass)
#      1536    0.001    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/context.py:443(is_for_this_target)
#      2336    0.001    0.000    0.003    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/base.py:384(_insert_get_constant_defn)
#      6387    0.001    0.000    0.001    0.000 {method 'release' of '_thread.RLock' objects}
#       933    0.001    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/ir/values.py:564(_get_reference)
#        99    0.001    0.000    0.002    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/ir/instructions.py:68(__init__)
#      2336    0.001    0.000    0.003    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/base.py:376(_insert_setattr_defn)
#      1264    0.001    0.000    0.064    0.000 <frozen importlib._bootstrap_external>:140(_path_stat)
# 2378/1950    0.001    0.000    0.002    0.000 <frozen abc>:121(__subclasscheck__)
#   341/340    0.001    0.000    0.018    0.000 <frozen importlib._bootstrap>:566(module_from_spec)
#       991    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:405(parent)
#       509    0.001    0.000    0.057    0.000 <frozen importlib._bootstrap_external>:150(_path_is_mode_type)
#       649    0.001    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/registry.py:67(__getitem__)
#       551    0.001    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/ctypes/__init__.py:511(cast)
#       321    0.001    0.000    0.002    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/byteflow.py:333(dispatch)
#      1984    0.001    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/binding/ffi.py:322(__init__)
#        52    0.001    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/dispatcher.py:199(__init__)
#        52    0.001    0.000    0.012    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/dispatcher.py:758(__init__)
#      1895    0.001    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/binding/ffi.py:339(detach)
#      3432    0.001    0.000    0.001    0.000 {built-in method builtins.min}
#         4    0.001    0.000    0.005    0.001 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/byteflow.py:94(run)
#       182    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/enum.py:367(__setitem__)
#       341    0.000    0.000    0.004    0.000 <frozen importlib._bootstrap_external>:567(_get_cached)
#         2    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/librosa/util/utils.py:238(valid_audio)
#       472    0.000    0.000    0.003    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/binding/ffi.py:260(close)
#       330    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:675(_validate_timestamp_pyc)
#        96    0.000    0.000    0.363    0.004 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/inspect.py:1051(findsource)
#       279    0.000    0.000    0.008    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/re/__init__.py:272(_compile)
#   319/273    0.000    0.000    0.333    0.001 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/compiler_lock.py:32(_acquire_compile_lock)
#       250    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/ctypes/__init__.py:393(__getitem__)
#       898    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/ir/builder.py:351(_insert)
#       445    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/contextlib.py:104(__init__)
#       319    0.000    0.000    0.115    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/extending.py:157(wrap)
#      2273    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#     67/31    0.000    0.000    0.004    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/re/_parser.py:456(_parse_sub)
#         9    0.000    0.000    0.000    0.000 {method 'readline' of '_io.BufferedReader' objects}
#       121    0.000    0.000    0.004    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/extending.py:352(_register)
#       135    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/interpreter.py:1832(store)
#      1389    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:1030(__exit__)
#    292/32    0.000    0.000    0.335    0.010 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/base.py:261(refresh)
#       315    0.000    0.000    0.003    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/interpreter.py:1794(_dispatch)
#       309    0.000    0.000    0.003    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/binding/dylib.py:15(add_symbol)
#    862/10    0.000    0.000    1.588    0.159 <frozen importlib._bootstrap>:233(_call_with_frames_removed)
#      1757    0.000    0.000    0.001    0.000 <frozen posixpath>:52(normcase)
#       168    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/inspect.py:2955(__init__)
#      1349    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/re/_parser.py:168(__getitem__)
#       139    0.000    0.000    0.004    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/importlib/metadata/__init__.py:931(read_text)
#      2465    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/ir/_utils.py:13(is_used)
#        69    0.000    0.000    0.041    0.001 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/codegen.py:1087(_load_defined_symbols)
#         4    0.000    0.000    0.000    0.000 {method 'outer' of 'numpy.ufunc' objects}
#       315    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/byteflow.py:1740(append)
#       344    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:198(cb)
#       161    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/typing.py:168(_type_check)
#      1320    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:134(<genexpr>)
#       386    0.000    0.000    0.003    0.000 <frozen importlib._bootstrap>:169(__enter__)
#        99    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/ir/instructions.py:133(_descr)
#    164/54    0.000    0.000    0.532    0.010 {built-in method builtins.__import__}
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/cpython/hashing.py:417(_Py_HashSecret_t)
#       108    0.000    0.000    0.002    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/codegen.py:1420(set_env)
#    209/63    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/re/_parser.py:178(getwidth)
#       602    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/typing.py:1320(__setattr__)
#      1045    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/imputils.py:37(decorate)
#       305    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/byteflow.py:153(_run_handle_exception)
#       331    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:599(_check_name_wrapper)
#      1389    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1026(__enter__)
#   316/268    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/ir/values.py:445(__init__)
#       261    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:216(_lock_unlock_module)
#      1907    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/types/functions.py:262(key)
#        65    0.000    0.000    0.000    0.000 {built-in method _ctypes.POINTER}
#      2299    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/types/abstract.py:93(__init__)
#         6    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numpy/core/function_base.py:24(linspace)
#       671    0.000    0.000    0.004    0.000 <frozen importlib._bootstrap>:392(cached)
#      1274    0.000    0.000    0.003    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/context.py:538(insert_global)
#       222    0.000    0.000    0.004    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/templates.py:1267(decorate)
#       121    0.000    0.000    0.002    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/templates.py:1001(make_intrinsic_template)
#       256    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/types/misc.py:124(__init__)
#      3522    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#        17    0.000    0.000    0.003    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/enum.py:499(__new__)
#       394    0.000    0.000    0.002    0.000 <frozen importlib._bootstrap_external>:1424(_path_importer_cache)
#       244    0.000    0.000    0.002    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/types/abstract.py:71(_type_reconstructor)
#        56    0.000    0.000    0.007    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/binding/module.py:11(parse_assembly)
#      1512    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/threading.py:1168(ident)
#   445/361    0.000    0.000    0.002    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/contextlib.py:141(__exit__)
#       341    0.000    0.000    0.002    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/compiler_lock.py:11(acquire)
#       319    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/interpreter.py:1518(_iter_inst)
#   330/314    0.000    0.000    0.004    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/typing.py:373(inner)
#       147    0.000    0.000    0.003    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/importlib/metadata/__init__.py:946(_normalized_name)
#      2102    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/binding/common.py:27(_is_shutting_down)
#      1330    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#       467    0.000    0.000    0.057    0.000 <frozen importlib._bootstrap_external>:159(_path_isfile)
#        18    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/options.py:45(_apply)
#       159    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/inspect.py:735(unwrap)
#       260    0.000    0.000    0.068    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/templates.py:1046(__init__)
#       987    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/binding/common.py:9(_decode_string)
#       148    0.000    0.000    0.002    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/binding/module.py:189(functions)
#        32    0.000    0.000    0.000    0.000 {built-in method _pickle.load}
#       344    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:71(__init__)
#       141    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/pathlib.py:56(parse_parts)
#       304    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/pathlib.py:536(__str__)
#         4    0.000    0.000    0.017    0.004 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/interpreter.py:1361(interpret)
#       330    0.000    0.000    0.003    0.000 <frozen importlib._bootstrap_external>:1146(path_stats)
#        32    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       260    0.000    0.000    0.002    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/target_extension.py:82(_get_local_target_checked)
#         1    0.000    0.000    0.007    0.007 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/np/arrayobj.py:1(<module>)
#        34    0.000    0.000    0.078    0.002 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/caching.py:323(__init__)
#       451    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/enum.py:688(__call__)
#        37    0.000    0.000    0.006    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/codegen.py:643(__init__)
#       926    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/re/_parser.py:240(__next)
#       144    0.000    0.000    0.002    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/binding/module.py:176(global_variables)
#       323    0.000    0.000    0.003    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/types/functions.py:266(augment)
#       243    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/extending.py:202(_overload_method_common)
#       986    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/byteflow.py:1715(get_inst)
#       658    0.000    0.000    0.001    0.000 {built-in method _abc._abc_instancecheck}
#         4    0.000    0.000    0.002    0.001 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/interpreter.py:982(peep_hole_delete_with_exit)
#       396    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/ir/values.py:860(__init__)
#       346    0.000    0.000    0.081    0.000 <frozen importlib._bootstrap_external>:1499(find_spec)
#       221    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/ir/types.py:206(__new__)
#       121    0.000    0.000    0.005    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/extending.py:435(_intrinsic)
#        79    0.000    0.000    0.002    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/typing.py:1376(__init__)
#      1045    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/imputils.py:28(lower)
#         4    0.000    0.000    0.002    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/analysis.py:23(compute_use_defs)
#      2380    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#       236    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/binding/ffi.py:255(__init__)
#      2380    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#        52    0.000    0.000    0.002    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/ir/values.py:936(__init__)
#       341    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/compiler_lock.py:15(release)
#      2026    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         4    0.000    0.000    0.045    0.011 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/np/ufunc/wrappers.py:138(build_ufunc_wrapper)
#    292/32    0.000    0.000    0.104    0.003 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/context.py:153(refresh)
#       445    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/contextlib.py:299(helper)
#       230    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/importlib/metadata/__init__.py:107(read)
#       181    0.000    0.000    0.000    0.000 {method 'sub' of 're.Pattern' objects}
#       325    0.000    0.000    0.002    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/bytecode.py:245(next)
#        18    0.000    0.000    0.002    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/ir.py:1323(dump)
#       330    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:48(_new_module)
#       325    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/target_extension.py:15(__getitem__)
#         1    0.000    0.000    0.007    0.007 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/np/arraymath.py:1(<module>)
#      1194    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#         5    0.000    0.000    0.008    0.002 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/codegen.py:651(_optimize_functions)
#       251    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/templates.py:182(signature)
#        34    0.000    0.000    0.080    0.002 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/caching.py:598(__init__)
#       472    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/ir/values.py:575(function_type)
#       163    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/inspect.py:167(get_annotations)
#      1734    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/types/functions.py:249(<genexpr>)
#        19    0.000    0.000    0.000    0.000 {built-in method builtins.dir}
#       146    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/ir/values.py:1104(__init__)
#        18    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/interpreter.py:1657(_remove_unused_temporaries)
#         8    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/callconv.py:777(_get_return_status)
#       140    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/pathlib.py:530(_make_child)
#        84    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/typing_extensions.py:3029(_collect_parameters)
#        16    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/cgutils.py:486(for_range)
#       189    0.000    0.000    0.010    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/ir/values.py:1172(descr)
#       168    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/ir/instructions.py:205(descr)
#      1238    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/templates.py:268(__init__)
#       140    0.000    0.000    0.003    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/importlib/metadata/_itertools.py:4(unique_everseen)
#       141    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/pathlib.py:484(_parse_args)
#        32    0.000    0.000    0.096    0.003 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/codegen.py:925(_unserialize)
#       760    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/types/npytypes.py:482(key)
#        58    0.000    0.000    0.005    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/decorators.py:26(jit)
#        58    0.000    0.000    0.059    0.001 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/decorators.py:202(wrapper)
#       143    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/ir/builder.py:756(load)
#         4    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/interpreter.py:1014(peep_hole_fuse_dict_add_updates)
#       184    0.000    0.000    0.000    0.000 <frozen genericpath>:121(_splitext)
#       195    0.000    0.000    0.000    0.000 <frozen posixpath>:140(basename)
#       654    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/typing.py:1266(_is_dunder)
#       346    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:920(find_spec)
#       243    0.000    0.000    0.004    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/templates.py:1180(make_overload_method_template)
#       386    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:173(__exit__)
#       292    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/binding/module.py:215(__init__)
#       189    0.000    0.000    0.009    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/ir/values.py:1174(<listcomp>)
#   445/353    0.000    0.000    0.005    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/contextlib.py:132(__enter__)
#        31    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/re/_compiler.py:511(_compile_info)
#        46    0.000    0.000    0.002    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/binding/targets.py:9(get_process_triple)
#        44    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/binding/executionengine.py:145(_find_module_ptr)
#       250    0.000    0.000    0.001    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/ctypes/__init__.py:386(__getattr__)
#        41    0.000    0.000    0.004    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/experimental/jitclass/overloads.py:23(decorator)
#      1950    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#   348/174    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/typing.py:3401(__getattribute__)
#       327    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#       780    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/inspect.py:378(isfunction)
#        11    0.000    0.000    0.000    0.000 {built-in method _imp.exec_dynamic}
#         2    0.000    0.000    0.457    0.228 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/inspect.py:1719(getouterframes)
# ...
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/builtins.py:497(TupleLt)
#         1    0.000    0.000    0.000    0.000 {built-in method time.time}
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/compiler_machinery.py:117(FunctionPass)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/builtins.py:354(BitwiseXor)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/types/functions.py:472(MakeFunctionLiteral)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/types/containers.py:114(PyArray)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/types/containers.py:601(SetPayload)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/errors.py:828(NumbaRuntimeError)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/config.py:184(validate)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/pycparser/ply/yacc.py:1470(GrammarError)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/audioread/ffdec.py:50(NotInstalledError)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/target_extension.py:149(NPyUfunc)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/parfors/parfor.py:747(has_setup)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/builtins.py:195(BinOpMul)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/ir/builder.py:99(_uniop_intrinsic_float)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/ir/instructions.py:311(Resume)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/ir/instructions.py:815(CatchClause)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/typeof.py:125(_typeof_complex)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/errors.py:63(NumbaDeprecationWarning)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/errors.py:729(RequireLiteralValue)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/errors.py:800(NumbaValueError)
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/callconv.py:931(NumpyErrorModel)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/builtins.py:190(BinOpSub)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/builtins.py:200(BinOpMul)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/stencils/__init__.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/types/abstract.py:360(Sequence)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/types/misc.py:186(EphemeralPointer)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/target_extension.py:133(CPU)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/builtins.py:388(UnaryPositive)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/builtins.py:477(TupleNe)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/types/abstract.py:367(MutableSequence)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/errors.py:108(NumbaIRAssumptionWarning)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/types/misc.py:47(RawPointer)
#         1    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.BytesIO' objects}
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:1016(ShutdownExecutorError)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/builtins.py:313(BitwiseRightShift)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/errors.py:627(DeprecationError)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/errors.py:643(UnsupportedParforsError)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/errors.py:686(CompilerError)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/__init__.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/pycparser/ply/yacc.py:2089(LALRError)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:1004(TerminatedWorkerError)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/builtins.py:318(BitwiseRightShift)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/builtins.py:329(BitwiseAnd)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/builtins.py:344(BitwiseOr)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/types/containers.py:122(MemoryView)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/errors.py:723(NonexistentTargetError)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/builtins.py:520(CmpOpIs)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/types/containers.py:374(StarArgUniTuple)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/errors.py:584(UnsupportedRewriteError)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/types/misc.py:19(Phantom)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/mathdecl.py:66(Math_floor_ceil)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/audioread/ffdec.py:54(ReadTimeoutError)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/builtins.py:349(BitwiseXor)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/builtins.py:931(Max)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/builtins.py:936(Min)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/ir/instructions.py:253(ConditionalBranch)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/errors.py:94(NumbaInvalidConfigWarning)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/errors.py:787(LiteralTypingError)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/compiler_machinery.py:123(AnalysisPass)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/builtins.py:339(BitwiseOr)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/listdecl.py:122(InplaceMulList)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/listdecl.py:138(ListEq)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/mathdecl.py:109(Math_isfinite)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/builtins.py:424(CmpOpGt)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/errors.py:82(NumbaTypeSafetyWarning)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/errors.py:590(IRError)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/types/misc.py:286(EllipsisType)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/ir/instructions.py:249(Branch)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/types/containers.py:379(BaseNamedTuple)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/errors.py:114(NumbaDebugInfoWarning)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/errors.py:597(RedefinedError)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/errors.py:657(TypingError)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/unsafe/__init__.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/np/__init__.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/errors.py:69(NumbaPendingDeprecationWarning)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/errors.py:650(ForbiddenConstruct)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/np/random/__init__.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/cpython/__init__.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/cpython/unsafe/__init__.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/errors.py:120(NumbaSystemWarning)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/np/polynomial/__init__.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/utils.py:187(<lambda>)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/errors.py:88(NumbaExperimentalFeatureWarning)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/functools.py:753(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/errors.py:804(NumbaTypeError)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/errors.py:816(NumbaNotImplementedError)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/errors.py:824(NumbaIndexError)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/errors.py:215(errmsg)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/annotations/__init__.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/joblib/externals/__init__.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/errors.py:808(NumbaAttributeError)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/errors.py:812(NumbaAssertionError)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/llvmlite/ir/builder.py:134(_triop_intrinsic)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/typing/context.py:148(init)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/errors.py:157(__init__)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/core/errors.py:820(NumbaKeyError)
#         1    0.000    0.000    0.000    0.000 /home/demancum/miniconda3/envs/cocola_test/lib/python3.11/site-packages/numba/misc/__init__.py:1(<module>)

# %%
import time
import random
import numpy as np

# Assuming train_dataset is already loaded or defined
n_samples = len(train_dataset)
n_trials = 100
times = []

# Measure the time it takes to compute train_dataset[i] for random indices
for _ in range(n_trials):
    i = random.randint(0, n_samples - 1)
    start_time = time.time()
    _ = train_dataset[i]
    end_time = time.time()
    times.append(end_time - start_time)

# Convert times to a numpy array for statistical computation
times = np.array(times)

# Compute statistics
mean_time = np.mean(times)
std_time = np.std(times)
median_time = np.median(times)
min_time = np.min(times)
max_time = np.max(times)

# Print results
print(f"Mean time: {mean_time:.6f} seconds")
print(f"Standard deviation: {std_time:.6f} seconds")
print(f"Median time: {median_time:.6f} seconds")
print(f"Minimum time: {min_time:.6f} seconds")
print(f"Maximum time: {max_time:.6f} seconds")
# Out:
# Mean time: 0.508575 seconds
# Standard deviation: 0.066567 seconds
# Median time: 0.519793 seconds
# Minimum time: 0.297949 seconds
# Maximum time: 0.764302 seconds

# %% [markdown]
# ## NO HPSS
#
# Mean time: 0.030078 seconds
#
# Standard deviation: 0.008805 seconds
#
# Median time: 0.028174 seconds
#
# Minimum time: 0.014488 seconds
#
# Maximum time: 0.050782 seconds

# %% [markdown]
# ## HPSS
#
# Mean time: 0.513520 seconds
#
# Standard deviation: 0.062310 seconds
#
# Median time: 0.532635 seconds
#
# Minimum time: 0.339727 seconds
#
# Maximum time: 0.616706 seconds

# %%
audio_path = "/speech/dbwork/mul/spielwiese4/students/demancum/musdb18hq/test/Al James - Schoolboy Facination/mixture.wav"

waveform, sr = torchaudio.load(str(audio_path))

audio = waveform.squeeze(0).cpu().numpy()

stft = librosa.stft(audio)#,
                    #n_fft=1024,
                    #win_length=400,
                    #hop_length=160)

harmonic_stft, percussive_stft = librosa.decompose.hpss(stft)

# %%
y_harm = librosa.istft(harmonic_stft)#,                     
                    #n_fft=1024,
                    #win_length=400,
                    #hop_length=160)
y_perc = librosa.istft(percussive_stft)#,                     
                    #n_fft=1024,
                    #win_length=400,
                    #hop_length=160)

# %%
import numpy as np
stereo = np.vstack((y_harm, y_perc))

    # Save as flac
torchaudio.save(
        "test.flac",
        torch.tensor(stereo),
        sample_rate=sr,
        format="flac"
    )

# %%
harmonic = torch.from_numpy(y_harm)
percussive = torch.from_numpy(y_perc)

# %%
harmonic_path = "harmonic.wav"
torchaudio.save(harmonic_path, harmonic, sr)

percussive_path = "percussive.wav"
torchaudio.save(percussive_path, percussive, sr)
